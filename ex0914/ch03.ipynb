# %%
# 가상환경 위치 확인
# !pip --version
# Out:
# pip 25.0.1 from D:\ces3356\ex0914\.venv\Lib\site-packages\pip (python 3.12)

# %%
# 패키지: 설치한 사용라이브러리 묶음
# !pip install dotenv
# Out:
# Requirement already satisfied: dotenv in .\.venv\lib\site-packages (0.9.9)
# Requirement already satisfied: python-dotenv in .\.venv\lib\site-packages (from dotenv) (1.2.3)
# [notice] A new release of pip is available: 25.0.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from dotenv import load_dotenv
# .env파일에 설정된 보안정보를 읽기.
load_dotenv()
# Out:
# True

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
import os

# 설정된 키값을 출력: *** 키값이 노출되지 않도록 앞부분(8글자만) 출력해본다 ***
print(f"키값은:{os.environ['OPENAI_API_KEY'][:8]}")
# Out:
# 키값은:sk-proj-

# %%
import os

key = os.getenv("OPENAI_API_KEY")

if key:
    print("✅ 키 설정됨")
else:
    print("❌ 키 없음")
# Out:
# ✅ 키 설정됨
