# %% [markdown]
# 랭스미스
# - gmail로그인
# - Organizations : Personal 무료한도적용
# -  왼쪽메뉴[Tracing] 프로젝트 등록 및 클릭 -> .env설정 및 테스트코드로 연결 검증
#
# *** 연결이 안될때
#
# jupyter파일 재시작
# VSCdoe 완전종료 및 재시작

# %%
# %pip --version
# Out:
# pip 25.0.1 from d:\ces3356\ex0914\.venv\Lib\site-packages\pip (python 3.12)
#
# Note: you may need to restart the kernel to use updated packages.

# %%
# 현재 노트북 커널에 설치합니다. 설치 후 커널을 재시작하세요.
# %pip install -U "langchain>=1,<2" langchain-openai python-dotenv langsmith langchain-teddynote
# Out:
# Requirement already satisfied: langchain<2,>=1 in .\.venv\lib\site-packages (1.4.0)
# Requirement already satisfied: langchain-openai in .\.venv\lib\site-packages (1.6.2)
# Requirement already satisfied: python-dotenv in .\.venv\lib\site-packages (1.2.3)
# Requirement already satisfied: langsmith in .\.venv\lib\site-packages (0.12.4)
# Requirement already satisfied: langchain-teddynote in .\.venv\lib\site-packages (0.5.4)
# Requirement already satisfied: langchain-core<2.0.0,>=1.6.0 in .\.venv\lib\site-packages (from langchain<2,>=1) (1.6.3)
# Requirement already satisfied: langgraph<1.3.0,>=1.2.11 in .\.venv\lib\site-packages (from langchain<2,>=1) (1.2.11)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in .\.venv\lib\site-packages (from langchain<2,>=1) (2.13.5)
# Requirement already satisfied: certifi>=2024.6.2 in .\.venv\lib\site-packages (from langchain-openai) (2026.7.22)
# Requirement already satisfied: openai<4.0.0,>=2.45.0 in .\.venv\lib\site-packages (from langchain-openai) (3.13.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in .\.venv\lib\site-packages (from langchain-openai) (0.14.0)
# Requirement already satisfied: anyio>=3.5.0 in .\.venv\lib\site-packages (from langsmith) (4.15.1)
# Requirement already satisfied: distro>=1.7.0 in .\.venv\lib\site-packages (from langsmith) (1.9.0)
# Requirement already satisfied: httpx2<3,>=2 in .\.venv\lib\site-packages (from langsmith) (2.12.0)
# Requirement already satisfied: orjson>=3.9.14 in .\.venv\lib\site-packages (from langsmith) (3.12.0)
# Requirement already satisfied: packaging>=23.2 in .\.venv\lib\site-packages (from langsmith) (26.3)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in .\.venv\lib\site-packages (from langsmith) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in .\.venv\lib\site-packages (from langsmith) (2.34.2)
# Requirement already satisfied: sniffio>=1.1 in .\.venv\lib\site-packages (from langsmith) (1.3.1)
# Requirement already satisfied: typing-extensions>=4.0.0 in .\.venv\lib\site-packages (from langsmith) (4.16.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in .\.venv\lib\site-packages (from langsmith) (0.17.1)
# Requirement already satisfied: websockets>=15.0 in .\.venv\lib\site-packages (from langsmith) (16.1.1)
# Requirement already satisfied: xxhash>=3.0.0 in .\.venv\lib\site-packages (from langsmith) (4.0.1)
# Requirement already satisfied: zstandard>=0.23.0 in .\.venv\lib\site-packages (from langsmith) (0.25.0)
# Requirement already satisfied: anthropic>=0.64.0 in .\.venv\lib\site-packages (from langchain-teddynote) (1.5.0)
# Requirement already satisfied: deepl>=1.22.0 in .\.venv\lib\site-packages (from langchain-teddynote) (1.32.0)
# Requirement already satisfied: feedparser>=6.0.11 in .\.venv\lib\site-packages (from langchain-teddynote) (6.0.14)
# Requirement already satisfied: kiwipiepy>=0.21.0 in .\.venv\lib\site-packages (from langchain-teddynote) (0.23.2)
# Requirement already satisfied: konlpy>=0.6.0 in .\.venv\lib\site-packages (from langchain-teddynote) (0.6.0)
# Requirement already satisfied: olefile>=0.47 in .\.venv\lib\site-packages (from langchain-teddynote) (0.47)
# Requirement already satisfied: pandas>=2.3.1 in .\.venv\lib\site-packages (from langchain-teddynote) (3.0.5)
# Requirement already satisfied: pdf2image>=1.17.0 in .\.venv\lib\site-packages (from langchain-teddynote) (1.17.0)
# Requirement already satisfied: pinecone-client>=6.0.0 in .\.venv\lib\site-packages (from langchain-teddynote) (6.0.0)
# Requirement already satisfied: pinecone-text>=0.11.0 in .\.venv\lib\site-packages (from langchain-teddynote) (0.11.0)
# Requirement already satisfied: rank-bm25>=0.2.2 in .\.venv\lib\site-packages (from langchain-teddynote) (0.2.2)
# Requirement already satisfied: tavily-python>=0.7.10 in .\.venv\lib\site-packages (from langchain-teddynote) (0.8.2)
# Requirement already satisfied: twine>=6.1.0 in .\.venv\lib\site-packages (from langchain-teddynote) (7.0.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in .\.venv\lib\site-packages (from anthropic>=0.64.0->langchain-teddynote) (0.18.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in .\.venv\lib\site-packages (from anthropic>=0.64.0->langchain-teddynote) (0.17.0)
# Requirement already satisfied: idna>=2.8 in .\.venv\lib\site-packages (from anyio>=3.5.0->langsmith) (3.19)
# Requirement already satisfied: feedparser-sgmllib<3,>=2 in .\.venv\lib\site-packages (from feedparser>=6.0.11->langchain-teddynote) (2.1.0)
# Requirement already satisfied: httpcore2==2.12.0 in .\.venv\lib\site-packages (from httpx2<3,>=2->langsmith) (2.12.0)
# Requirement already satisfied: truststore>=0.10 in .\.venv\lib\site-packages (from httpx2<3,>=2->langsmith) (0.10.4)
# Requirement already satisfied: h11>=0.16 in .\.venv\lib\site-packages (from httpcore2==2.12.0->httpx2<3,>=2->langsmith) (0.16.0)
# Requirement already satisfied: kiwipiepy_model<0.24,>=0.23 in .\.venv\lib\site-packages (from kiwipiepy>=0.21.0->langchain-teddynote) (0.23.0)
# Requirement already satisfied: numpy in .\.venv\lib\site-packages (from kiwipiepy>=0.21.0->langchain-teddynote) (2.5.3)
# Requirement already satisfied: tqdm in .\.venv\lib\site-packages (from kiwipiepy>=0.21.0->langchain-teddynote) (4.70.1)
# Requirement already satisfied: JPype1>=0.7.0 in .\.venv\lib\site-packages (from konlpy>=0.6.0->langchain-teddynote) (1.7.1)
# Requirement already satisfied: lxml>=4.1.0 in .\.venv\lib\site-packages (from konlpy>=0.6.0->langchain-teddynote) (6.1.3)
# Requirement already satisfied: httpx<1.0.0,>=0.23.0 in .\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain<2,>=1) (0.28.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in .\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain<2,>=1) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in .\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain<2,>=1) (0.0.19)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in .\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain<2,>=1) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in .\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain<2,>=1) (9.1.4)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in .\.venv\lib\site-packages (from langgraph<1.3.0,>=1.2.11->langchain<2,>=1) (4.2.0)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in .\.venv\lib\site-packages (from langgraph<1.3.0,>=1.2.11->langchain<2,>=1) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.5.0,>=0.4.2 in .\.venv\lib\site-packages (from langgraph<1.3.0,>=1.2.11->langchain<2,>=1) (0.4.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in .\.venv\lib\site-packages (from pandas>=2.3.1->langchain-teddynote) (2.9.0.post0)
# Requirement already satisfied: tzdata in .\.venv\lib\site-packages (from pandas>=2.3.1->langchain-teddynote) (2026.4)
# Requirement already satisfied: pillow in .\.venv\lib\site-packages (from pdf2image>=1.17.0->langchain-teddynote) (12.3.0)
# Requirement already satisfied: pinecone-plugin-interface<0.0.8,>=0.0.7 in .\.venv\lib\site-packages (from pinecone-client>=6.0.0->langchain-teddynote) (0.0.7)
# Requirement already satisfied: urllib3>=1.26.5 in .\.venv\lib\site-packages (from pinecone-client>=6.0.0->langchain-teddynote) (2.7.0)
# Requirement already satisfied: mmh3<5.0.0,>=4.1.0 in .\.venv\lib\site-packages (from pinecone-text>=0.11.0->langchain-teddynote) (4.1.0)
# Requirement already satisfied: nltk<4.0.0,>=3.9.1 in .\.venv\lib\site-packages (from pinecone-text>=0.11.0->langchain-teddynote) (3.10.3)
# Requirement already satisfied: types-requests<3.0.0,>=2.25.0 in .\.venv\lib\site-packages (from pinecone-text>=0.11.0->langchain-teddynote) (2.33.0.20260906)
# Requirement already satisfied: annotated-types>=0.6.0 in .\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<2,>=1) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.5 in .\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<2,>=1) (2.46.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in .\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<2,>=1) (0.4.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in .\.venv\lib\site-packages (from requests>=2.0.0->langsmith) (3.5.1)
# Requirement already satisfied: regex in .\.venv\lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2026.9.10)
# Requirement already satisfied: readme-renderer>=35.0 in .\.venv\lib\site-packages (from twine>=6.1.0->langchain-teddynote) (46.0)
# Requirement already satisfied: keyring>=21.2.0 in .\.venv\lib\site-packages (from twine>=6.1.0->langchain-teddynote) (25.7.0)
# Requirement already satisfied: rfc3986>=1.4.0 in .\.venv\lib\site-packages (from twine>=6.1.0->langchain-teddynote) (2.0.0)
# Requirement already satisfied: rich>=14.3.3 in .\.venv\lib\site-packages (from twine>=6.1.0->langchain-teddynote) (15.0.0)
# Requirement already satisfied: id in .\.venv\lib\site-packages (from twine>=6.1.0->langchain-teddynote) (1.6.1)
# Requirement already satisfied: httpcore==1.* in .\.venv\lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain<2,>=1) (1.0.9)
# Requirement already satisfied: jsonpointer>=1.9 in .\.venv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.6.0->langchain<2,>=1) (3.1.1)
# Requirement already satisfied: pywin32-ctypes>=0.2.0 in .\.venv\lib\site-packages (from keyring>=21.2.0->twine>=6.1.0->langchain-teddynote) (0.2.3)
# Requirement already satisfied: jaraco.classes in .\.venv\lib\site-packages (from keyring>=21.2.0->twine>=6.1.0->langchain-teddynote) (3.4.0)
# Requirement already satisfied: jaraco.functools in .\.venv\lib\site-packages (from keyring>=21.2.0->twine>=6.1.0->langchain-teddynote) (4.6.0)
# Requirement already satisfied: jaraco.context in .\.venv\lib\site-packages (from keyring>=21.2.0->twine>=6.1.0->langchain-teddynote) (6.1.2)
# Requirement already satisfied: ormsgpack>=1.12.0 in .\.venv\lib\site-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.11->langchain<2,>=1) (1.12.2)
# Requirement already satisfied: defusedxml in .\.venv\lib\site-packages (from nltk<4.0.0,>=3.9.1->pinecone-text>=0.11.0->langchain-teddynote) (0.7.1)
# Requirement already satisfied: click in .\.venv\lib\site-packages (from nltk<4.0.0,>=3.9.1->pinecone-text>=0.11.0->langchain-teddynote) (8.5.0)
# Requirement already satisfied: joblib in .\.venv\lib\site-packages (from nltk<4.0.0,>=3.9.1->pinecone-text>=0.11.0->langchain-teddynote) (1.6.0)
# Requirement already satisfied: six>=1.5 in .\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas>=2.3.1->langchain-teddynote) (1.17.0)
# Requirement already satisfied: nh3>=0.2.14 in .\.venv\lib\site-packages (from readme-renderer>=35.0->twine>=6.1.0->langchain-teddynote) (0.3.7)
# Requirement already satisfied: docutils>=0.21.2 in .\.venv\lib\site-packages (from readme-renderer>=35.0->twine>=6.1.0->langchain-teddynote) (0.23)
# Requirement already satisfied: Pygments>=2.5.1 in .\.venv\lib\site-packages (from readme-renderer>=35.0->twine>=6.1.0->langchain-teddynote) (2.21.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in .\.venv\lib\site-packages (from rich>=14.3.3->twine>=6.1.0->langchain-teddynote) (4.2.0)
# Requirement already satisfied: colorama in .\.venv\lib\site-packages (from tqdm->kiwipiepy>=0.21.0->langchain-teddynote) (0.4.6)
# Requirement already satisfied: mdurl~=0.1 in .\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=14.3.3->twine>=6.1.0->langchain-teddynote) (0.1.2)
# Requirement already satisfied: more-itertools in .\.venv\lib\site-packages (from jaraco.classes->keyring>=21.2.0->twine>=6.1.0->langchain-teddynote) (11.1.0)
# Requirement already satisfied: cloudpickle>=3.0 in .\.venv\lib\site-packages (from joblib->nltk<4.0.0,>=3.9.1->pinecone-text>=0.11.0->langchain-teddynote) (3.1.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# # 정상 로드 확인 테스트
# print("OpenAI 키:", os.getenv("OPENAI_API_KEY")[:8] + "...")
# print("LANGSMITH 키:", os.getenv("LANGSMITH_API_KEY")[:8] + "...")
# print("LangSmith 프로젝트:", os.getenv("LANGSMITH_PROJECT"))

# %% [markdown]
# from dotenv import load_dotenv
# import os
#
# # .env 파일 로드
# load_dotenv()
#
# # 정상 로드 확인
# print("OpenAI 키:", os.getenv("OPENAI_API_KEY")[:8] + "...")
# print("LANGSMITH 키:", os.getenv("LANGSMITH_API_KEY")[:8] + "...")
# print("LangSmith 프로젝트:", os.getenv("LANGSMITH_PROJECT"))

# %%
# %pip install -U langchain langchain-openai langsmith langgraph
# Out:
# Requirement already satisfied: langchain in .\.venv\lib\site-packages (1.4.0)
# Requirement already satisfied: langchain-openai in .\.venv\lib\site-packages (1.6.2)
# Requirement already satisfied: langsmith in .\.venv\lib\site-packages (0.12.4)
# Requirement already satisfied: langgraph in .\.venv\lib\site-packages (1.2.11)
# Requirement already satisfied: langchain-core<2.0.0,>=1.6.0 in .\.venv\lib\site-packages (from langchain) (1.6.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in .\.venv\lib\site-packages (from langchain) (2.13.5)
# Requirement already satisfied: certifi>=2024.6.2 in .\.venv\lib\site-packages (from langchain-openai) (2026.7.22)
# Requirement already satisfied: openai<4.0.0,>=2.45.0 in .\.venv\lib\site-packages (from langchain-openai) (3.13.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in .\.venv\lib\site-packages (from langchain-openai) (0.14.0)
# Requirement already satisfied: anyio>=3.5.0 in .\.venv\lib\site-packages (from langsmith) (4.15.1)
# Requirement already satisfied: distro>=1.7.0 in .\.venv\lib\site-packages (from langsmith) (1.9.0)
# Requirement already satisfied: httpx2<3,>=2 in .\.venv\lib\site-packages (from langsmith) (2.12.0)
# Requirement already satisfied: orjson>=3.9.14 in .\.venv\lib\site-packages (from langsmith) (3.12.0)
# Requirement already satisfied: packaging>=23.2 in .\.venv\lib\site-packages (from langsmith) (26.3)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in .\.venv\lib\site-packages (from langsmith) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in .\.venv\lib\site-packages (from langsmith) (2.34.2)
# Requirement already satisfied: sniffio>=1.1 in .\.venv\lib\site-packages (from langsmith) (1.3.1)
# Requirement already satisfied: typing-extensions>=4.0.0 in .\.venv\lib\site-packages (from langsmith) (4.16.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in .\.venv\lib\site-packages (from langsmith) (0.17.1)
# Requirement already satisfied: websockets>=15.0 in .\.venv\lib\site-packages (from langsmith) (16.1.1)
# Requirement already satisfied: xxhash>=3.0.0 in .\.venv\lib\site-packages (from langsmith) (4.0.1)
# Requirement already satisfied: zstandard>=0.23.0 in .\.venv\lib\site-packages (from langsmith) (0.25.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in .\.venv\lib\site-packages (from langgraph) (4.2.0)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in .\.venv\lib\site-packages (from langgraph) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.5.0,>=0.4.2 in .\.venv\lib\site-packages (from langgraph) (0.4.4)
# Requirement already satisfied: idna>=2.8 in .\.venv\lib\site-packages (from anyio>=3.5.0->langsmith) (3.19)
# Requirement already satisfied: httpcore2==2.12.0 in .\.venv\lib\site-packages (from httpx2<3,>=2->langsmith) (2.12.0)
# Requirement already satisfied: truststore>=0.10 in .\.venv\lib\site-packages (from httpx2<3,>=2->langsmith) (0.10.4)
# Requirement already satisfied: h11>=0.16 in .\.venv\lib\site-packages (from httpcore2==2.12.0->httpx2<3,>=2->langsmith) (0.16.0)
# Requirement already satisfied: httpx<1.0.0,>=0.23.0 in .\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (0.28.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in .\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in .\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (0.0.19)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in .\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in .\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (9.1.4)
# Requirement already satisfied: ormsgpack>=1.12.0 in .\.venv\lib\site-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph) (1.12.2)
# Requirement already satisfied: jiter<1,>=0.16.0 in .\.venv\lib\site-packages (from openai<4.0.0,>=2.45.0->langchain-openai) (0.17.0)
# Requirement already satisfied: annotated-types>=0.6.0 in .\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.5 in .\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.46.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in .\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in .\.venv\lib\site-packages (from requests>=2.0.0->langsmith) (3.5.1)
# Requirement already satisfied: urllib3<3,>=1.26 in .\.venv\lib\site-packages (from requests>=2.0.0->langsmith) (2.7.0)
# Requirement already satisfied: regex in .\.venv\lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2026.9.10)
# Requirement already satisfied: httpcore==1.* in .\.venv\lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain) (1.0.9)
# Requirement already satisfied: jsonpointer>=1.9 in .\.venv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.6.0->langchain) (3.1.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from dotenv import load_dotenv
import os

# .env 파일 로드
load_dotenv()

# 정상 로드 확인
print("OpenAI 키:", os.getenv("OPENAI_API_KEY")[:8] + "...")
print("LANGSMITH 키:", os.getenv("LANGSMITH_API_KEY")[:8] + "...")
print("LangSmith 프로젝트:", os.getenv("LANGSMITH_PROJECT"))
# Out:
# OpenAI 키: sk-proj-...
# LANGSMITH 키: lsv2_pt_...
# LangSmith 프로젝트: test0914

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-4o-mini")
response = llm.invoke("대한민국의 수도는 어디인가요?")
print(response.content)

# 랭스미스 Tracing에서 확인하기
# Out:
# 대한민국의 수도는 서울입니다.

# %%
from langchain_openai import ChatOpenAI
from langchain_core.tools import tool
from langchain.agents import create_agent

@tool
def get_weather(city: str) -> str:
    """Get weather for a given city."""
    return f"It's always sunny in {city}!"

llm = ChatOpenAI(model="gpt-4o-mini", temperature=0)
agent = create_agent(model=llm, tools=[get_weather])

result = agent.invoke({
    "messages": [("user", "San Francisco 날씨 어때?")]
})

print(result["messages"][-1].content)
# Out:
# 샌프란시스코의 날씨는 항상 맑습니다!

# %%
# !pip install langchain_teddynote
from langchain_teddynote import logging

# %%
# 랭스미스 추척하기.
logging.langsmith("test0914", set_enable=True)
# Out:
# LangSmith 추적을 시작합니다.
# [프로젝트명]
# test0914

# %%
logging.langsmith("test0914", set_enable=False)# 랭스미스 추척하지 않기.
# Out:
# LangSmith 추적을 하지 않습니다.
