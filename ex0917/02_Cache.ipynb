# %%
from dotenv import load_dotenv
from langchain_teddynote import logging

# .env의 API KEY 불러오기
load_dotenv()

# LangSmith 실행 기록
logging.langsmith("CH04-Models")
# Out:
# LangSmith 추적을 시작합니다.
# [프로젝트명]
# CH04-Models

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import PromptTemplate

# LLM 모델 생성
llm = ChatOpenAI(
    model="gpt-4.1-mini",
    temperature=0
)

# 프롬프트 생성
prompt = PromptTemplate.from_template(
    "{country}에 대해서 200자 내외로 요약해줘"
)

# 프롬프트 → LLM 연결
chain = prompt | llm

# %%
# %%time

response = chain.invoke({"country": "한국"})

print(response.content)
# Out:
# 한국은 동아시아에 위치한 한반도의 남쪽에 자리한 국가로, 공식 명칭은 대한민국이다. 서울이 수도이며, 약 5천만 명의 인구가 거주한다. 한국은 첨단 기술과 문화 산업이 발달한 경제 강국으로, 반도체, 자동차, K-팝, 한류 드라마 등이 세계적으로 유명하다. 역사적으로는 고대 삼국시대부터 현대에 이르기까지 풍부한 문화유산을 가지고 있으며, 민주주의와 경제 발전을 동시에 이룬 나라로 평가받는다.
# CPU times: total: 188 ms
# Wall time: 1.8 s

# %%
from langchain_core.globals import set_llm_cache
from langchain_core.caches import InMemoryCache

# 메모리 캐시 활성화
set_llm_cache(InMemoryCache())

# %%
# %%time

response = chain.invoke({"country": "한국"})

print(response.content)
# Out:
# 한국은 동아시아에 위치한 한반도의 남쪽에 자리한 국가로, 수도는 서울이다. 고유한 역사와 문화를 지니며, 한글이라는 독창적인 문자 체계를 사용한다. 경제적으로는 IT, 자동차, 반도체 등 첨단 산업이 발달했으며, K-팝과 한류 문화가 전 세계적으로 인기를 끌고 있다. 민주주의 국가로서 교육과 기술 발전에 힘쓰고 있다.
# CPU times: total: 31.2 ms
# Wall time: 1.9 s

# %%
# %pip install -U langchain-community
# Out:
# Collecting langchain-community
#   Using cached langchain_community-0.4.2-py3-none-any.whl.metadata (3.4 kB)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain-community)
#   Using cached aiohttp-3.14.3-cp312-cp312-win_amd64.whl.metadata (8.5 kB)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain-community)
#   Using cached httpx_sse-0.4.3-py3-none-any.whl.metadata (9.7 kB)
# Collecting langchain-classic<2.0.0,>=1.0.7 (from langchain-community)
#   Using cached langchain_classic-1.0.8-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.0 in .\.venv\lib\site-packages (from langchain-community) (1.6.3)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in .\.venv\lib\site-packages (from langchain-community) (0.12.6)
# Requirement already satisfied: numpy>=1.26.2 in .\.venv\lib\site-packages (from langchain-community) (2.5.3)
# Collecting pydantic-settings<3.0.0,>=2.10.1 (from langchain-community)
#   Using cached pydantic_settings-2.15.0-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in .\.venv\lib\site-packages (from langchain-community) (6.0.3)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in .\.venv\lib\site-packages (from langchain-community) (2.34.2)
# Collecting sqlalchemy<3.0.0,>=1.4.0 (from langchain-community)
#   Using cached sqlalchemy-2.0.54-cp312-cp312-win_amd64.whl.metadata (9.9 kB)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in .\.venv\lib\site-packages (from langchain-community) (9.1.4)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Using cached aiohappyeyeballs-2.7.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Using cached aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting attrs>=17.3.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Using cached attrs-26.1.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Using cached frozenlist-1.8.0-cp312-cp312-win_amd64.whl.metadata (21 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Using cached multidict-6.8.0-cp312-cp312-win_amd64.whl.metadata (5.4 kB)
# Collecting propcache>=0.2.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading propcache-0.5.4-cp312-cp312-win_amd64.whl.metadata (25 kB)
# Requirement already satisfied: typing_extensions>=4.4 in .\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (4.16.0)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading yarl-1.25.1-cp312-cp312-win_amd64.whl.metadata (115 kB)
# Collecting langchain-text-splitters<2.0.0,>=1.1.2 (from langchain-classic<2.0.0,>=1.0.7->langchain-community)
#   Using cached langchain_text_splitters-1.1.2-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in .\.venv\lib\site-packages (from langchain-classic<2.0.0,>=1.0.7->langchain-community) (2.13.5)
# Requirement already satisfied: httpx<1.0.0,>=0.23.0 in .\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (0.28.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in .\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in .\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (0.0.19)
# Requirement already satisfied: packaging>=23.2.0 in .\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (26.3)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in .\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (0.17.1)
# Requirement already satisfied: anyio>=3.5.0 in .\.venv\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (4.15.1)
# Requirement already satisfied: distro>=1.7.0 in .\.venv\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.9.0)
# Requirement already satisfied: httpx2<3,>=2 in .\.venv\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (2.13.0)
# Requirement already satisfied: orjson>=3.9.14 in .\.venv\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.12.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in .\.venv\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: sniffio>=1.1 in .\.venv\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.3.1)
# Requirement already satisfied: websockets>=15.0 in .\.venv\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (16.1.1)
# Requirement already satisfied: xxhash>=3.0.0 in .\.venv\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (4.0.1)
# Requirement already satisfied: zstandard>=0.23.0 in .\.venv\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.25.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in .\.venv\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.3)
# Requirement already satisfied: typing-inspection>=0.4.0 in .\.venv\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (0.4.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in .\.venv\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.5.1)
# Requirement already satisfied: idna<4,>=2.5 in .\.venv\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.19)
# Requirement already satisfied: urllib3<3,>=1.26 in .\.venv\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.8.0)
# Requirement already satisfied: certifi>=2023.5.7 in .\.venv\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2026.7.22)
# Collecting greenlet>=1 (from sqlalchemy<3.0.0,>=1.4.0->langchain-community)
#   Using cached greenlet-3.5.6-cp312-cp312-win_amd64.whl.metadata (3.9 kB)
# Requirement already satisfied: httpcore==1.* in .\.venv\lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.4.0->langchain-community) (1.0.9)
# Requirement already satisfied: h11>=0.16 in .\.venv\lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.4.0->langchain-community) (0.16.0)
# Requirement already satisfied: httpcore2==2.13.0 in .\.venv\lib\site-packages (from httpx2<3,>=2->langsmith<1.0.0,>=0.1.125->langchain-community) (2.13.0)
# Requirement already satisfied: truststore>=0.10 in .\.venv\lib\site-packages (from httpx2<3,>=2->langsmith<1.0.0,>=0.1.125->langchain-community) (0.10.4)
# Requirement already satisfied: jsonpointer>=1.9 in .\.venv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.0->langchain-community) (3.1.1)
# Requirement already satisfied: annotated-types>=0.6.0 in .\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.7->langchain-community) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.5 in .\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.7->langchain-community) (2.46.5)
# Using cached langchain_community-0.4.2-py3-none-any.whl (2.4 MB)
# Using cached aiohttp-3.14.3-cp312-cp312-win_amd64.whl (476 kB)
# Using cached httpx_sse-0.4.3-py3-none-any.whl (9.0 kB)
# Using cached langchain_classic-1.0.8-py3-none-any.whl (1.0 MB)
# Using cached pydantic_settings-2.15.0-py3-none-any.whl (69 kB)
# Using cached sqlalchemy-2.0.54-cp312-cp312-win_amd64.whl (2.2 MB)
# Using cached aiohappyeyeballs-2.7.1-py3-none-any.whl (15 kB)
# Using cached aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Using cached attrs-26.1.0-py3-none-any.whl (67 kB)
# Using cached frozenlist-1.8.0-cp312-cp312-win_amd64.whl (44 kB)
# Using cached greenlet-3.5.6-cp312-cp312-win_amd64.whl (324 kB)
# Using cached langchain_text_splitters-1.1.2-py3-none-any.whl (35 kB)
# Using cached multidict-6.8.0-cp312-cp312-win_amd64.whl (51 kB)
# Downloading propcache-0.5.4-cp312-cp312-win_amd64.whl (46 kB)
# Downloading yarl-1.25.1-cp312-cp312-win_amd64.whl (102 kB)
# Installing collected packages: propcache, multidict, httpx-sse, greenlet, frozenlist, attrs, aiohappyeyeballs, yarl, sqlalchemy, aiosignal, pydantic-settings, aiohttp, langchain-text-splitters, langchain-classic, langchain-community
# Successfully installed aiohappyeyeballs-2.7.1 aiohttp-3.14.3 aiosignal-1.4.0 attrs-26.1.0 frozenlist-1.8.0 greenlet-3.5.6 httpx-sse-0.4.3 langchain-classic-1.0.8 langchain-community-0.4.2 langchain-text-splitters-1.1.2 multidict-6.8.0 propcache-0.5.4 pydantic-settings-2.15.0 sqlalchemy-2.0.54 yarl-1.25.1
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_community.cache import SQLiteCache
from langchain_core.globals import set_llm_cache
import os

# cache 폴더가 없으면 생성
os.makedirs("cache", exist_ok=True)

# SQLite 파일에 캐시 저장
set_llm_cache(
    SQLiteCache(database_path="cache/llm_cache.db")
)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_21812\3862135802.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.cache import SQLiteCache

# %%
# %%time

response = chain.invoke({"country": "한국"})

print(response.content)
# Out:
# 한국은 동아시아에 위치한 한반도의 남쪽에 자리한 국가로, 수도는 서울이다. 고유한 역사와 문화를 지니며, 한글이라는 독창적인 문자 체계를 사용한다. 경제적으로는 IT, 자동차, 반도체 등 첨단 산업이 발달했으며, K-팝과 한류 문화가 전 세계적으로 인기를 끌고 있다. 민주주의 국가로서 교육과 기술 발전에 힘쓰고 있다.
# CPU times: total: 46.9 ms
# Wall time: 1.72 s
