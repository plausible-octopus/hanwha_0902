# %%
# %pip install -U huggingface_hub langchain-huggingface
# Out:
# ...
#   Using cached huggingface_hub-1.31.0-py3-none-any.whl.metadata (16 kB)
# ...
#   Using cached fsspec-2026.7.0-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached hf_xet-1.6.0-cp38-abi3-win_amd64.whl.metadata (4.9 kB)
# ...
#   Using cached tokenizers-0.23.2-cp310-abi3-win_amd64.whl.metadata (10 kB)
# ...
# Using cached huggingface_hub-1.31.0-py3-none-any.whl (798 kB)
# ...
# Using cached fsspec-2026.7.0-py3-none-any.whl (206 kB)
# Using cached hf_xet-1.6.0-cp38-abi3-win_amd64.whl (4.0 MB)
# Using cached tokenizers-0.23.2-cp310-abi3-win_amd64.whl (2.9 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from dotenv import load_dotenv
from langchain_teddynote import logging

# .env의 API KEY / Token 불러오기
load_dotenv()

# LangSmith 추적
logging.langsmith("CH04-Models")
# Out:
# LangSmith 추적을 시작합니다.
# [프로젝트명]
# CH04-Models

# %%
import os

# .env에 Hugging Face 토큰이 들어있는지 확인
print(os.getenv("HUGGINGFACEHUB_API_TOKEN") is not None)
# Out:
# False

# %%
from langchain_core.prompts import PromptTemplate

# 질문 템플릿
template = """Question: {question}

Answer:"""

prompt = PromptTemplate.from_template(template)

# %%
from langchain_huggingface import HuggingFaceEndpoint
from langchain_core.output_parsers import StrOutputParser

# Hugging Face Endpoint 사용 예시
# 실제 실행 시 HUGGINGFACEHUB_API_TOKEN 필요

# llm = HuggingFaceEndpoint(
#     repo_id="microsoft/Phi-3-mini-4k-instruct",
#     max_new_tokens=256,
#     temperature=0.1,
#     task="text-generation",
#     huggingfacehub_api_token=os.environ["HUGGINGFACEHUB_API_TOKEN"],
# )

# chain = prompt | llm | StrOutputParser()
